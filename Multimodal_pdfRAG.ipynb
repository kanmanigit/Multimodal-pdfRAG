# %% [markdown]
# ## MultiModal PDF-RAG with Langchain and Milvus Vector database

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
#  ### Load and parse Multimodal PDF

# %%
import os

os.environ["PATH"] += os.pathsep + "/opt/homebrew/bin"
from unstructured.partition.pdf import partition_pdf 

raw_pdf_elements=partition_pdf(
    filename="data/SIABestPractices.pdf", 
    strategy="hi_res",                                      
    extract_images_in_pdf=True,                            
    extract_image_block_output_dir="extracted_data1",
    infer_table_structure=True,  
    )
# Out:
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# The `max_size` parameter is deprecated and will be removed in v4.26. Please specify in `size['longest_edge'] instead`.

# %%
#raw_pdf_elements

# %% [markdown]
# each elements has properties like:
#     element.text        # The actual text (if it's a text-based element)
#     element.category    # Type of element (e.g., "NarrativeText", "Title", etc.)
#     element.metadata    # Metadata like page number, coordinates, etc.

# %%
for ele in raw_pdf_elements:
    print(f"page_content: {ele.text}")
    print(f"category: {ele.category}")
    print(f"Pagenumber: {ele.metadata.page_number}")
    print(f"image: {ele.metadata.image_path}")


    print("----")
# Out:
# page_content: Home (/s/)
# category: Title
# Pagenumber: 1
# image: None
# ----
# page_content: Engage Updates Product Centers Resources
# category: Header
# Pagenumber: 1
# image: None
# ----
# page_content: (Pore
# category: Title
# Pagenumber: 1
# image: None
# ----
# page_content:
# category: Image
# Pagenumber: 1
# image: extracted_data1/figure-1-1.jpg
# ----
# page_content: More
# category: Title
# Pagenumber: 1
# image: None
# ----
# page_content: Have a Question? Ask the Community
# category: Title
# Pagenumber: 1
# image: None
# ----
# page_content: (Q Search...
# category: Title
# Pagenumber: 1
# image: None
# ----
# page_content: Search...
# category: Title
# Pagenumber: 1
# image: None
# ----
# page_content: Search )
# category: Title
# Pagenumber: 1
# image: None
# ----
# page_content: Search
# category: NarrativeText
# Pagenumber: 1
# image: None
# ----
# page_content: SIA Best Practices: Architecture, Conﬁguration, Security, and Operations
# category: Title
# Pagenumber: 1
# image: None
# ----
# page_content: Secure Infrastructure Access (SIA) offers an agentless, SaaS solution for securing privileged access to organizational assets across hybrid and cloud environments. It supports access with zero standing privileges (ZSP) or using vaulted credentials, reducing the risk of standing privileges and including session isolation and monitoring. This document offers the current technical best practices for deploying and conﬁguring SIA securely, architecture for SIA connectors, general conﬁguration of SIA, and the operational aspects associated with maintaining a functional deployment.
# category: NarrativeText
# Pagenumber: 1
# image: None
# ----
# page_content: Following  Flag
# category: Image
# Pagenumber: 1
# image: extracted_data1/figure-1-2.jpg
# ----
# page_content: Related Articles
# category: Title
# Pagenumber: 1
# image: None
# ----
# page_content: 21-Oct-2024 Knowledge Article
# category: NarrativeText
# Pagenumber: 1
# image: None
# ----
# page_content: Article Total View Count
# category: Title
# Pagenumber: 1
# image: None
# ----
# page_content: Security Best Practices for Hardening Your CyberArk Identity Deployment (/s/article/Security-Best- Practices-for-Hardening-Your-CyberArk-Identity- Deployment) 1.48K
# category: NarrativeText
# Pagenumber: 1
# image: None
# ----
# page_content: 1,962
# category: UncategorizedText
# Pagenumber: 1
# image: None
# ----
# page_content: Title
# category: Title
# Pagenumber: 1
# image: None
# ----
# page_content: SIA Best Practices: Architecture, Conﬁguration, Security, and Operations
# category: NarrativeText
# Pagenumber: 1
# image: None
# ----
# page_content: Workforce Password Manager Best Practices (/s/article/Workforce-Password-Manager-Best- Practices) 404
# category: NarrativeText
# Pagenumber: 1
# image: None
# ----
# page_content: Author
# category: Title
# Pagenumber: 1
# image: None
# ----
# page_content: Jake DeSantis, Cloud Services Excellence Manager, Security Services
# category: NarrativeText
# Pagenumber: 1
# image: None
# ----
# page_content: PTA security postures best practices (/s/article/PTA-se‐ curity-postures-best-practices) 948
# category: NarrativeText
# Pagenumber: 1
# image: None
# ----
# page_content: Blog Details
# category: Title
# Pagenumber: 1
# image: None
# ----
# page_content: Introduction
# category: Title
# Pagenumber: 1
# image: None
# ----
# page_content: CyberArk Secure Cloud Access (SCA) Policy Best Practices (/s/article/CyberArk-Secure-Cloud-Access-SCA- Policy-Best-Practices) 625
# category: NarrativeText
# Pagenumber: 1
# image: None
# ----
# page_content: A critical component of any identity security program is privileged session management. Secure Infrastructure Access (SIA) offers an agentless, SaaS solution for securing privileged access to organizational assets across hybrid and cloud environments. It supports access with zero standing privileges (ZSP) or using vaulted credentials, reducing the risk of standing privileges and including session isolation and monitoring. System
# category: NarrativeText
# Pagenumber: 1
# image: None
# ----
# page_content: @ COOKIE PREFERENCES 7
# category: Image
# Pagenumber: 1
# image: extracted_data1/figure-1-3.jpg
# ----
# page_content: administrators, DevOps engineers, application owners, and others get VPN-less secure access to Windows, Linux, databases, and Kubernetes via an MFA-secured connection, using their preferred client with the right access for the required duration. For access with vaulted credentials, SIA leverages existing access control policies, requiring only the deployment of the SIA connector.
# category: NarrativeText
# Pagenumber: 2
# image: None
# ----
# page_content: This document offers the current technical best practices for deploying and conﬁguring SIA securely, architecture for SIA connectors, general conﬁguration of SIA, and the operational aspects associated with maintaining a functional deployment.
# category: NarrativeText
# Pagenumber: 2
# image: None
# ----
# page_content: Table of Contents
# category: Title
# Pagenumber: 2
# image: None
# ----
# page_content: Audience Security Architecture Conﬁguration Operation Additional Reading
# category: NarrativeText
# Pagenumber: 2
# image: None
# ----
# page_content: Audience
# category: Title
# Pagenumber: 2
# image: None
# ----
# page_content: This technical article is designed for those serving the function of CyberArk Administrator and Architect/Subject Matter Expert (https://community.cyberark.com/s/article/Roles-Responsibilities-and-Stafﬁng-Considerations- for-Your-Identity-Security-Program-Part-1) roles. The article can be used by those deploying and operating Secure Infrastructure Access connectors in their environment as well as those responsible for the design and rollout of the solution.
# category: NarrativeText
# Pagenumber: 2
# image: None
# ----
# page_content: Security
# category: Title
# Pagenumber: 2
# image: None
# ----
# page_content: Opt for Zero Standing Privilege (ZSP)
# category: Title
# Pagenumber: 2
# image: None
# ----
# page_content: CyberArk recommends leveraging SIA for ZSP wherever possible. ZSP involves dynamically provisioning privileged access to users or systems on an as-needed basis, granting temporary and scoped privileges only when required for speciﬁc tasks or workﬂows. By implementing ZSP, organizations can reduce the number of privileged accounts with permanent access rights. This approach helps to minimize the attack surface and prevent unauthorized users from exploiting prolonged access to critical resources.
# category: NarrativeText
# Pagenumber: 2
# image: None
# ----
# page_content: For your domain-based accounts, remove access from the AD accounts or groups to the required target machines. If you’re using secondary personal privilege accounts, make sure to delete standing access to the AD accounts. CyberArk recommends a policy-driven approach to controlling local group membership on target systems. Consider using domain group policies or client management software to control the membership of the privileged local groups on target systems.
# category: NarrativeText
# Pagenumber: 2
# image: None
# ----
# page_content: \ By istomeConsidarusing COOKIE PREFERENCES }s
# category: Image
# Pagenumber: 2
# image: extracted_data1/figure-2-4.jpg
# ----
# page_content: Best Practices for Adopting and Implementing Secure Cloud Access (SCA) (/s/article/Best-Practices-for-Adopting- and-Implementing-Secure-Cloud-Access-SCA) 875
# category: NarrativeText
# Pagenumber: 2
# image: None
# ----
# page_content: Sort by:  S…  Most Recent Activity  t
# category: Image
# Pagenumber: 2
# image: extracted_data1/figure-2-5.jpg
# ----
# page_content:
# category: Image
# Pagenumber: 2
# image: extracted_data1/figure-2-6.jpg
# ----
# page_content: LiadD (CyberArk Community Manager)
# category: Title
# Pagenumber: 2
# image: None
# ----
# page_content: (/s/proﬁle/005Ht00000AibqgIAB) (CyberArk) published a new version of this Knowledge Article.
# category: ListItem
# Pagenumber: 2
# image: None
# ----
# page_content: 21 October 2024 at 11:52
# category: UncategorizedText
# Pagenumber: 2
# image: None
# ----
# page_content: (/s/feed/0D5Ht0000AUrPfHKQV)
# category: Title
# Pagenumber: 2
# image: None
# ----
# page_content: Like Comment
# category: Title
# Pagenumber: 2
# image: None
# ----
# page_content: e
# category: Image
# Pagenumber: 2
# image: extracted_data1/figure-2-7.jpg
# ----
# page_content: Write a comment...
# category: NarrativeText
# Pagenumber: 2
# image: None
# ----
# page_content:
# category: Image
# Pagenumber: 2
# image: extracted_data1/figure-2-8.jpg
# ----
# page_content: LiadD (CyberArk Community Manager) (/s/proﬁle/005Ht00000AibqgIAB) (CyberArk) unpublished this Knowledge Article. 21 October 2024 at 11:52 (/s/feed/0D5Ht0000AUrPf7KQF)
# category: ListItem
# Pagenumber: 2
# image: None
# ----
# page_content: Like Comment
# category: Title
# Pagenumber: 2
# image: None
# ----
# page_content: e
# category: Image
# Pagenumber: 2
# image: extracted_data1/figure-2-9.jpg
# ----
# page_content: Write a comment...
# category: NarrativeText
# Pagenumber: 2
# image: None
# ----
# page_content: $
# category: Image
# Pagenumber: 2
# image: extracted_data1/figure-2-10.jpg
# ----
# page_content: Sal (CyberArk Community Manager)
# category: ListItem
# Pagenumber: 2
# image: None
# ----
# page_content: (/s/proﬁle/0052J000009GKbpQAG) (CyberArk) published a new version of this Knowledge Article. 14 October 2024 at 15:37 (/s/feed/0D5Ht0000AUPHxIKQX)
# category: ListItem
# Pagenumber: 2
# image: None
# ----
# page_content: Like Comment
# category: ListItem
# Pagenumber: 2
# image: None
# ----
# page_content: In the case of local accounts, identify the privileged users who don’t need ongoing access to target machines and remove their access.
# category: NarrativeText
# Pagenumber: 3
# image: None
# ----
# page_content: For system accounts used for break-glass access, it is recommended to leave the strongest target user (like domain admin, built-in local admins, or root) with a password and/or ssh key access through vaulting and rotation of the credential using PAM.
# category: NarrativeText
# Pagenumber: 3
# image: None
# ----
# page_content: Restricting access to Target Systems
# category: Title
# Pagenumber: 3
# image: None
# ----
# page_content: Once the SIA deployment is complete and the user adoption rate is high, customers are encouraged to conﬁgure internal network ACLs in a way that allow connectivity from the SIA servers only. For Windows servers, this means allowing only access over port 445 (SMB), 139 & 135 (MSRPC), and 3389 (RDP) and for Linux, 22 (SSH). For more information about SIA network requirements, see Network requirements | CyberArk Docs (https://docs.cyberark.com/DPA/Latest/en/Content/Introduction/dpa_network-requirements.htm).
# category: NarrativeText
# Pagenumber: 3
# image: None
# ----
# page_content: It’s important to have a contingency plan in place if SIA were to be unavailable. For this, make sure that your network teams can enable access to the target systems from another “Break Glass” session host in the environment. Alternatively, have a plan in place to modify the ACLs in a way that allow access to the systems from another user subnet. Please see the “Break Glass” section below for more information regarding how to handle break glass.
# category: NarrativeText
# Pagenumber: 3
# image: None
# ----
# page_content: Strong Accounts
# category: Title
# Pagenumber: 3
# image: None
# ----
# page_content: About
# category: Title
# Pagenumber: 3
# image: None
# ----
# page_content: Strong accounts are privileged accounts with elevated access rights that provide temporary accounts used for ZSP access. Strong accounts can be considered “Service Accounts” in that they are used by the SIA service to automate access for the ZSP ﬂow. To provision ephemeral users, SIA needs to access a strong account, which can create the ephemeral users on the target machines and delete them when the session ends.
# category: NarrativeText
# Pagenumber: 3
# image: None
# ----
# page_content: Separate strong accounts should be created for Windows and Databases (such as MSSQL). These will need to be onboarded separately in the SIA portal.
# category: NarrativeText
# Pagenumber: 3
# image: None
# ----
# page_content: Vault & Rotate
# category: Title
# Pagenumber: 3
# image: None
# ----
# page_content: Strong accounts can either be speciﬁed in SIA directly or you can conﬁgure SIA to retrieve the account from the vault. Customers are advised to opt for vaulting and rotating the strong accounts. By vaulting strong accounts, Organizations can comply with business security objective and mitigate malicious or risky account usage. Additionally, regular rotation of strong account passwords helps to mitigate the risk of credential theft or misuse by malicious actors. This can be integrated with self-hosted deployments of CyberArk Privileged Access Management (PAM) by leveraging usage plugins to automate the management of strong account credentials.
# category: NarrativeText
# Pagenumber: 3
# image: None
# ----
# page_content: max—————— COOKIE PREFERENCES ) @ ) ~
# category: Image
# Pagenumber: 3
# image: extracted_data1/figure-3-11.jpg
# ----
# page_content: e
# category: Image
# Pagenumber: 3
# image: extracted_data1/figure-3-12.jpg
# ----
# page_content: Write a comment...
# category: Header
# Pagenumber: 3
# image: None
# ----
# page_content:
# category: Image
# Pagenumber: 3
# image: extracted_data1/figure-3-13.jpg
# ----
# page_content: Sal (CyberArk Community Manager)
# category: ListItem
# Pagenumber: 3
# image: None
# ----
# page_content: (/s/proﬁle/0052J000009GKbpQAG) (CyberArk) published a new version of this Knowledge Article. 14 October 2024 at 15:34 (/s/feed/0D5Ht0000AUPHu0KQH)
# category: ListItem
# Pagenumber: 3
# image: None
# ----
# page_content: Like Comment
# category: Title
# Pagenumber: 3
# image: None
# ----
# page_content: e
# category: Image
# Pagenumber: 3
# image: extracted_data1/figure-3-14.jpg
# ----
# page_content: Write a comment...
# category: NarrativeText
# Pagenumber: 3
# image: None
# ----
# page_content: @ “¥
# category: Image
# Pagenumber: 3
# image: extracted_data1/figure-3-15.jpg
# ----
# page_content: James Creamer (CyberArk)
# category: ListItem
# Pagenumber: 3
# image: None
# ----
# page_content: (/s/proﬁle/005500000062PIFAA2) (CyberArk) published a new version of this Knowledge Article. 17 July 2024 at 20:13 (/s/feed/0D5Ht0000AQRLyMKQX)
# category: ListItem
# Pagenumber: 3
# image: None
# ----
# page_content: Like Comment
# category: Title
# Pagenumber: 3
# image: None
# ----
# page_content: e
# category: Image
# Pagenumber: 3
# image: extracted_data1/figure-3-16.jpg
# ----
# page_content: Write a comment...
# category: NarrativeText
# Pagenumber: 3
# image: None
# ----
# page_content:
# category: Image
# Pagenumber: 3
# image: extracted_data1/figure-3-17.jpg
# ----
# page_content: Sal (CyberArk Community Manager)
# category: ListItem
# Pagenumber: 3
# image: None
# ----
# page_content: (/s/proﬁle/0052J000009GKbpQAG) (CyberArk) published a new version of this Knowledge Article. 15 July 2024 at 16:01 (/s/feed/0D5Ht0000APt3A7KQJ)
# category: ListItem
# Pagenumber: 3
# image: None
# ----
# page_content: Like Comment
# category: Title
# Pagenumber: 3
# image: None
# ----
# page_content: e
# category: Image
# Pagenumber: 3
# image: extracted_data1/figure-3-18.jpg
# ----
# page_content: Write a comment...
# category: NarrativeText
# Pagenumber: 3
# image: None
# ----
# page_content: Least Privilege
# category: Title
# Pagenumber: 4
# image: None
# ----
# page_content: While the strong accountant may be a member of the Domain Administrators group, this doesn't follow the principle of least privilege and is not considered best practice. To adhere to the principle of least privilege and separation of duties, organizations should subdivide strong accounts into privilege silos. This granular approach helps to ensure that the strong account does not have widespread access throughout your environment. You may also choose to select SIA strong accounts based on credential boundary or network area which may also help align access rights with organizational structures and business requirements.
# category: NarrativeText
# Pagenumber: 4
# image: None
# ----
# page_content: Strong accounts should be a domain account. CyberArk does not recommend setting up a local account with the same name and the same password on all the target machines. It must be a member of the local Administrators group on each target machine. You can manage this using the Restricted Groups Security Settings in Group Policy.
# category: NarrativeText
# Pagenumber: 4
# image: None
# ----
# page_content: File Action View Help es%\acnla\b am YM Computer Configuration *) Group Name > Members Member Of v Gi Policies 8% Administrators 11 Software Settings v 15 Windows Settings (Gl Name Resolution Policy Administrators Properties ? x {S| Scripts (Startup/Shutdown) 8 Deployed Printers Configure Membership for Administrators vB Securty Settings 55 Account Policies ‘Member of thie group: cca Pots (CYBRIDPASrong Ba 3 Event Log 1 Restricted Groups a A System Services (GB Registry Co File System [Tay Wired Network (IEEE 802.3) Policie Fy Windows Defender Firewall with & Network List Manager Policies Ths gmp s amenber cf £Eif Wireless Network (IEEE 802.11) Pol es re nisi sown belongs Md 5 Public Key Policies 1 Seftware Restriction Policies, [5 Application Control Policies & IP Security Policies on Active Direc Sy Advanced Audit Policy Configural < > Remove Ok Cancel Aoply
# category: Image
# Pagenumber: 4
# image: extracted_data1/figure-4-19.jpg
# ----
# page_content: Figure 1: Adding the Strong Account to Local Administrators Group via Group Policy
# category: FigureCaption
# Pagenumber: 4
# image: None
# ----
# page_content: Additionally, conﬁgure the “Deny Logon through Remote Desktop Services”, “Deny Logon Locally”, “Deny log on as a batch job”, and “Deny log on as a service” for the strong account in domain group policies.
# category: NarrativeText
# Pagenumber: 4
# image: None
# ----
# page_content: COOKIE PREFERENCES
# category: Image
# Pagenumber: 4
# image: extracted_data1/figure-4-20.jpg
# ----
# page_content: $
# category: Image
# Pagenumber: 4
# image: extracted_data1/figure-4-21.jpg
# ----
# page_content: Sal (CyberArk Community Manager)
# category: ListItem
# Pagenumber: 4
# image: None
# ----
# page_content: (/s/proﬁle/0052J000009GKbpQAG) (CyberArk) published this new Knowledge Article. 10 July 2024 at 04:33 (/s/feed/0D5Ht0000APqoc0KQB)
# category: ListItem
# Pagenumber: 4
# image: None
# ----
# page_content: Like Comment
# category: Title
# Pagenumber: 4
# image: None
# ----
# page_content: e
# category: Image
# Pagenumber: 4
# image: extracted_data1/figure-4-22.jpg
# ----
# page_content: Write a comment...
# category: NarrativeText
# Pagenumber: 4
# image: None
# ----
# page_content: =
# category: UncategorizedText
# Pagenumber: 4
# image: None
# ----
# page_content: J Group Policy Management Editor - a x File. Action View Help e9\an\/XOS\bm ‘J DPA-Strong [AIO.CYBRLOCAL] Policy + Policy * Policy Setting a“ Y @& Computer Configuration WiCreate a token object Not Defined ¥ Gi Policies settings (Gj Create global objects Not Defined 2a eer Settings LU) Create permanent shared objects Not Defined > | Name Resolution Policy LU Create symbolic links Not Defined Scripts (Startup/Shutdoown) {G) Debug programs Not Defined Deployed Printers (Gj Deny access to this computer from the network Not Defined vB Security Settings @] > Bil Account Policies Ui Deny log on as a service DPA-Strong v qj Local Policies (Deny tog on locally DPA-Strong > Gi Audit Policy {Gj Deny log on through Remote Desktop Services DPA-Strong > Gj User Rights Assignment (i Enable computer and user accounts to be trusted for delegation Not Defined > dj Security Options Li Force shutdown from a remote system Not Defined > Gj Event Log B Generate security audits Not Defined 1 Restricted Groups {Gj impersonate a client after authentication Not Defined ‘System Services Uj Increase a process working set Not Defined Registry Uj Increase scheduling priority Not Defined File System G) Load and unload device drivers Not Defined Wired Network (IEEE 802.3) Policie Not Defined > Windows Defender Firewall with & Not Defined "Network List Manager Policies UG Log on as a service Not Defined > Eg Wines Newark (EEO | ge ting deity totes ae Y || CA Modify an object label Not Defined g 2 Modif firmware enviranmant valies Not Nafined 9
# category: Image
# Pagenumber: 5
# image: extracted_data1/figure-5-23.jpg
# ----
# page_content: Figure 2: User Rights Assignment Restrictions on Domain Strong Account
# category: FigureCaption
# Pagenumber: 5
# image: None
# ----
# page_content: As an AD account, strong accounts should be disabled for delegation. Select the “Account is sensitive and cannot be delegated” option in the account properties.
# category: NarrativeText
# Pagenumber: 5
# image: None
# ----
# page_content: DPA-Strong Properties 2 x Pubished Certficates Member Of Password Replication Diskin Object Securty Environment Sessions, Remote control Remote Desktop Services Profle cOM+ Attrbute Edtor General Address Account Profile Telephones Organization User logon name: |DPA-Strong ‘@cybrlocal v] Userlogon name (ere-Windows 2000}: cyeR\ [DPA-Strong | ‘Logon Hours... Log On To... Dunlock account ‘Account options: DAccount is disabled i O)Smart card is required for interactive logon T)Use only Kerberes DES encryption types forthis account ¥ Account expires Never OEnd of: Saturday July 6, 2024 Cancel || Apply Help
# category: Image
# Pagenumber: 5
# image: extracted_data1/figure-5-24.jpg
# ----
# page_content: Figure 3: Conﬁgure Strong Account Object with "Account is sensitive and cannot be delegated"
# category: FigureCaption
# Pagenumber: 5
# image: None
# ----
# page_content: @ COOKIE PREFERENCES
# category: Image
# Pagenumber: 5
# image: extracted_data1/figure-5-25.jpg
# ----
# page_content: Although it’s very easy to conﬁgure the strong account as a local admin on target systems, CyberArk recommends taking this a step further to ensure the strong account only has the ability to manage local users on the system and no more.
# category: NarrativeText
# Pagenumber: 6
# image: None
# ----
# page_content: Domain Controllers
# category: Title
# Pagenumber: 6
# image: None
# ----
# page_content: Cyberark does not support and does not recommend enabling connections via RDP to domain controllers using SIA. This is because SIA creates a local user and there are none on domain controllers. Any user created on a domain controller is a domain user, which has more permissions than necessary and is therefore less secure.
# category: NarrativeText
# Pagenumber: 6
# image: None
# ----
# page_content: Connector Server Hardening
# category: Title
# Pagenumber: 6
# image: None
# ----
# page_content: Unlike traditional solutions like Privilege Session Manager (PSM), SIA connectors do not require Remote Desktop Services roles or licensing. This mitigates many vulnerabilities that may arise with the additional footprint. However, hardening the SIA connector servers is still essential for enhancing security and protecting against potential threats and vulnerabilities. Organizations can achieve this by applying CIS Benchmark (https://www.cisecurity.org/benchmark/microsoft_windows_server) or Microsoft Security Baseline (https://www.microsoft.com/en-us/download/details.aspx?id=55319) group policies or conﬁgurations to the SIA connector servers. By doing so, organizations can address common security weaknesses and ensure that the servers are conﬁgured according to established security standards and guidelines.
# category: NarrativeText
# Pagenumber: 6
# image: None
# ----
# page_content: Avoid Wildcards in Recurring Access Policies
# category: Title
# Pagenumber: 6
# image: None
# ----
# page_content: Using wildcards for Hostnames in ZSP policy rules should be avoided due to the risk of granting unfettered access to all machines within an environment. While wildcards may seem convenient, they can inadvertently expose sensitive resources to unauthorized users or roles depending on the risk rating and security level of the asset being accessed and the asset executing the initial session. Instead, organizations should prioritize more precise criteria, such as "starts with" matching, Subscription IDs, VPC identiﬁers, or speciﬁc attributes.
# category: NarrativeText
# Pagenumber: 6
# image: None
# ----
# page_content: On-premises assets operator Hostname/FODN, Domainysuttic
# category: Image
# Pagenumber: 6
# image: extracted_data1/figure-6-26.jpg
# ----
# page_content: On-premises assets operator Hostname/FODN, Domainysuttic
# category: Table
# Pagenumber: 6
# image: None
# ----
# page_content: Figure 4: Recurring access policy sowing the use of starts with
# category: NarrativeText
# Pagenumber: 6
# image: None
# ----
# page_content: Gm conn paneeaencee) COOKIE PREFERENCES ) @ :)
# category: Image
# Pagenumber: 6
# image: extracted_data1/figure-6-27.jpg
# ----
# page_content: Azure assets Custom tag (optional) Add the or evap) Note: In 4 policy tionship m i tags is “ane! Key Value (optional Application CyberArk @ Remove Remove + Aaa
# category: Image
# Pagenumber: 7
# image: extracted_data1/figure-7-28.jpg
# ----
# page_content: Figure 5: Azure recurring access policy for VMs allowing connectivity to machines matching the tag named Application with a value of "CyberArk"
# category: NarrativeText
# Pagenumber: 7
# image: None
# ----
# page_content: Architecture
# category: Title
# Pagenumber: 7
# image: None
# ----
# page_content: Redundancy and Scalability
# category: Title
# Pagenumber: 7
# image: None
# ----
# page_content: To ensure redundancy and scalability, pool multiple connectors by estimating the number of concurrent sessions, latency, and geographical locations through historical logging data showing connections to targets over RDP and SSH. Deploy at least two Connector servers in a Connector pool for high availability and load balancing. Assign connectors and deﬁne target sets; SIA will use an algorithm to choose the SIA connector with the minimum number of active sessions connected to it within all Connector Pools for the target host. Install SIA on a dedicated machine, though PSM/P and SIA can be installed on the same machine if necessary. Refer to the documentation (https://docs.cyberark.com/dpa/latest/en/Content/Setup/dpa-connector- bp.htm#:~:text=Assign%20connectors%20and%20deﬁne%20target%20sets) on where to install connectors.
# category: NarrativeText
# Pagenumber: 7
# image: None
# ----
# page_content: 7 al ge | Mybomain.com ‘Web Taffe, TCP 44 DPISSH/DB Trac: GC) rt
# category: Image
# Pagenumber: 7
# image: extracted_data1/figure-7-29.jpg
# ----
# page_content: COOKIE PREFERENCES
# category: Image
# Pagenumber: 7
# image: extracted_data1/figure-7-30.jpg
# ----
# page_content: Proximity to target systems
# category: Title
# Pagenumber: 8
# image: None
# ----
# page_content: Deploy SIA Connectors as close to target servers as possible. A target host should be conﬁgured under one Connector Pool. Whenever possible, the closer the Connector Servers in a Connector Pool are to the intended target hosts, the better. If you have a ﬂat network that spans across On-Prem, AWS, Azure, etc., an "On-Prem" connector can be used for all vaulted credentials. In a disparate network that is segmented and not interconnected, use an On-Prem connector in each network zone for vaulted credentials. For ZSP, install the respective type of SIA connector (AWS, Azure, GCP, On-Prem) in each disparate zone. For AWS, if you are onboarding multiple accounts instead of the organization, create a new Pool encompassing all the servers you wish to connect to. Ensure connectivity to any additional accounts and add them to the pool.
# category: NarrativeText
# Pagenumber: 8
# image: None
# ----
# page_content: Operating System Considerations
# category: Title
# Pagenumber: 8
# image: None
# ----
# page_content: It’s important to understand the factors that may inﬂuence the decision between installing SIA connectors on Windows or on Linux. First, it’s important to call out that there is no performance difference between a SIA connector installed on Linux vs. installed on Windows. However, if you need to connect to Windows machines via ZSP, at least one of the connectors in the pool must be installed on Windows, to handle the provisioning. SIA for RDP and SIA for SSH work by forwarding the TCP trafﬁc, but you do need a Windows Connector to use the ZSP functionality on Windows.
# category: NarrativeText
# Pagenumber: 8
# image: None
# ----
# page_content: You can deploy more Linux connectors if you want more redundancy for connectivity. This is more common in cloud infrastructure than on-premises. If a particular network contains Linux only, then there is no need to install a Windows connector into the environment. Consider network requirements when deploying the connector servers. Users will need access to CyberArk’s SaaS over ports 443 and 22, and access to the targets from the connectors over port 22.
# category: NarrativeText
# Pagenumber: 8
# image: None
# ----
# page_content: Conﬁguration
# category: Title
# Pagenumber: 8
# image: None
# ----
# page_content: Recurring Access Policies
# category: Title
# Pagenumber: 8
# image: None
# ----
# page_content: Limit policies to boost performance. In practice, this means carefully deﬁning and restricting the scope of policies applied within SIA to ensure that they do not unnecessarily grow and cause performance bottlenecks. Limiting policies can involve setting precise criteria for access, reducing the number of simultaneous operations allowed, and optimizing the rules to ensure they are as efﬁcient as possible. This helps maintain a high level of performance and responsiveness within the SIA environment.
# category: NarrativeText
# Pagenumber: 8
# image: None
# ----
# page_content: Access Policy Naming
# category: Title
# Pagenumber: 8
# image: None
# ----
# page_content: The ﬁrst item that you deﬁne when creating a recurring access policy is the name. Consider using ﬁelds like the following when creating your access policy naming convention:
# category: NarrativeText
# Pagenumber: 8
# image: None
# ----
# page_content: Deﬁnition Example The type of target the access policy PRD; DEV; QA applies to. This could be Production targets, Development environment targets, or QA.
# category: Table
# Pagenumber: 8
# image: None
# ----
# page_content: Field Name
# category: Title
# Pagenumber: 8
# image: None
# ----
# page_content: Environment
# category: Title
# Pagenumber: 8
# image: None
# ----
# page_content: | @ COOKIE PREFERENCES
# category: Image
# Pagenumber: 8
# image: extracted_data1/figure-8-31.jpg
# ----
# page_content: Location The location the targets exist. This may be NA; EMEA; APJ; EU; more applicable to customers who have LATAM targets spread globally. Application Some customers will deﬁne their targets in <Application sets that are based on the applications Abbreviation> they host. Criticality Consider deﬁning access policy names PH; PM; PL; NPH; based on the criticality of the targets that NPM; MPL the policy allows users to access. These can be in the form of “Production High/Mid/Low”; Non-Production High/Mid/Low; etc. Time Frame Consider including other recurring access Jun-Jul; Q1; H2; etc. policy details like the timeframe when access is meant to be permitted.
# category: Table
# Pagenumber: 9
# image: None
# ----
# page_content: CyberArk recommends also relying on the existing naming convention ﬁelds that have been developed within your environment. For instance, you may already have a naming convention for targets that you use in your environment such as WIN-PH-NA-PRD-SRV-002 which would deﬁne the second windows server that is a production high-impact system in North America. Your recurring access policy could be named similar to this, allowing users to access those Windows Production High-impact systems in North America. i.e. WIN-PH-NA- PRD
# category: NarrativeText
# Pagenumber: 9
# image: None
# ----
# page_content: Time Frame
# category: Title
# Pagenumber: 9
# image: None
# ----
# page_content: The recurring access policy timeframe can be used to set a span of time that allows the deﬁned members to connect to the deﬁned targets. Use the time frame in scenarios where you need to limit users access only during a project timeline, contract timelines, or when you must put a timeframe around the access during certain change windows. The timeframe in an access policy can be automated in these scenarios using the startDate and endDate parameters in the update authorization policy
# category: NarrativeText
# Pagenumber: 9
# image: None
# ----
# page_content: (https://docs.cyberark.com/DPA/Latest/en/Content/APIs/dpa_policies.htm) API.
# category: Title
# Pagenumber: 9
# image: None
# ----
# page_content: Access Rules
# category: Title
# Pagenumber: 9
# image: None
# ----
# page_content: Access rules in recurring access policies deﬁne if the rule applies to windows and/or linux machines, which users or roles the access rule applies (members), the days of the week that the access is permitted, and the timeframe on those days that access is permitted. Access rules also deﬁne session settings like how long the sessions can be and how much idle time is permitted before the session is automatically closed. Members: When deﬁning the members in an policy, opt for using roles rather than individual users when possible. Using roles instead of users allows admins to more easily control and deﬁne which users have access to targets in the environment. Consider creating roles speciﬁc to the recurring access policies and naming them to align with the recurring access policy name.
# category: NarrativeText
# Pagenumber: 9
# image: None
# ----
# page_content: Days of the week and Timeframe: Deﬁne the days of the week that make the most sense for allowing access to the targets Set the timeframe during business hours or when work on those targets is most necessary. You
# category: NarrativeText
# Pagenumber: 9
# image: None
# ----
# page_content: ‘en @ COOKIE PREFERENCES ) _
# category: Image
# Pagenumber: 9
# image: extracted_data1/figure-9-32.jpg
# ----
# page_content: may want to be more or less restrictive based on the criticality of the resources in question. If your recurring access policies allow access to dev systems, you may want to be more lenient with the access; for production systems, think about how the access timeframe can be more restrictive. Length of sessions and permitted idle time: The length of sessions should be a balance between how much time is required by the members to perform their work on average. Being too restrictive with the length of the session can cause the sessions to close sooner than the work can be completed. It’s important to allow enough time for the work to be completed. Deﬁne policies for lower-risk targets where the length of the sessions and the idle time are longer. For more critical targets, carefully deﬁne the length of the sessions and the idle time just enough to allow users to perform their work and end the sessions if they are idle for an unacceptable length of time. For these more critical systems, no more than 2 hours of idle time should be considered.
# category: NarrativeText
# Pagenumber: 10
# image: None
# ----
# page_content: For windows assets, the access rules can deﬁne which group that the strong account will add the ephemeral user to. The principal of least privilege should be followed here. CyberArk recommends deﬁning a custom group on the target systems using group policy and customizing user rights assignments for that group to granularly limit what the user can do on those systems. Alternatively, customers can use built-in groups like Administrators, Power Users, or Remote Desktop users. In this case, choose the group that grants the lowest level of privilege while still allowing the end user to accomplish their tasks.
# category: NarrativeText
# Pagenumber: 10
# image: None
# ----
# page_content: For Linux assets, the access rules can deﬁne which local privileged user the session will assume when SIA connects the end user to the target system. CyberArk recommends deﬁning a user with only the right privileges on the system for the connection, disabling password and ssh key login for that user, and allowing only ssh certiﬁcate-based auth. For each authorized connection, SIA generates and signs an SSH certiﬁcate with the CA private key which is used to authenticate the end user to the target machine as the existing local user of the target machine. This SSH certiﬁcate is invalidated for further use within minutes, so that no one else can use it. Every new authorized connection request, even by the same user to the same target, generates a new SSH certiﬁcate. You can read about how to manage the SSH CA public key for SIA connections to Linux systems here
# category: NarrativeText
# Pagenumber: 10
# image: None
# ----
# page_content: (https://docs.cyberark.com/dpa/latest/en/Content/Setup/dpa_deploy_public_key.htm).
# category: NarrativeText
# Pagenumber: 10
# image: None
# ----
# page_content: Attributed Based Access Control
# category: Title
# Pagenumber: 10
# image: None
# ----
# page_content: SIA can connect users to Windows and Linux targets in cloud environments like AWS, Azure, and GCP. Customers may use a simple windows connector to allow their users to do so, however it’s better practice to use the built-in attribute-based access control to more granularly deﬁne access policies. Attribute-based access control in recurring access policies deﬁne both the available platform resources and the level of privileges allowed to the end user. The access policy assigns an access proﬁle to the end user, which contains permissions for accessing the target.
# category: NarrativeText
# Pagenumber: 10
# image: None
# ----
# page_content: AWS Azure GCP Account Subscription IDs Project IDs Region VPC Regions Resource Groups Regions VPC Networks
# category: Table
# Pagenumber: 10
# image: None
# ----
# page_content: VPC
# category: Image
# Pagenumber: 10
# image: extracted_data1/figure-10-33.jpg
# ----
# page_content: Custom Tags*
# category: Header
# Pagenumber: 11
# image: None
# ----
# page_content: VNet IDs
# category: Title
# Pagenumber: 11
# image: None
# ----
# page_content: Labels
# category: ListItem
# Pagenumber: 11
# image: None
# ----
# page_content: Custom Tags*
# category: Title
# Pagenumber: 11
# image: None
# ----
# page_content: *Using custom tags and labels gives you very granular control over your cloud assets. Many customers already leverage custom tags in their environments and may leverage those same tags in SIA’s recurring access policies.
# category: NarrativeText
# Pagenumber: 11
# image: None
# ----
# page_content: Operation
# category: Title
# Pagenumber: 11
# image: None
# ----
# page_content: Monitoring
# category: Title
# Pagenumber: 11
# image: None
# ----
# page_content: Regular monitoring of the SIA service on connector servers is crucial for maintaining system health and performance. Utilize monitoring tools to track key metrics such as CPU usage, memory utilization, network throughput, and disk I/O. Implement comprehensive logging to capture detailed information about SIA operations, including connection attempts, successes, and failures. Regularly review these logs to identify patterns or anomalies that could indicate potential issues. Establish a baseline of normal operating parameters to quickly detect deviations that may require attention. Additionally, consider setting up automated monitoring solutions that provide real-time visibility into the SIA service’s status and performance, helping to proactively address issues before they escalate.
# category: NarrativeText
# Pagenumber: 11
# image: None
# ----
# page_content: When using Zero Standing Privilege, it’s important to consider how access to target systems with ephemeral accounts is done to be able to properly audit these sessions. Below is an example of a session audit log that shows the connection details for a session that used SIA for JIT access:
# category: NarrativeText
# Pagenumber: 11
# image: None
# ----
# page_content: Activities Tecan 4 re sername eton — serace michael. mcaughey@cyberark.cloud.20885 has discon... 9.2004 14708 4M DPAWindowssesion andes micusimenugheeyberadoudzoees Endy rege css vent detalls Service dita 19.2024 11338 DA Winsouesemionansas — minasienugnaSeybearecousannss aa yea Prag hess DPAWindowssesion started micusimenugheeyberadoudz0ees Stay rege Accs
# category: Image
# Pagenumber: 11
# image: extracted_data1/figure-11-34.jpg
# ----
# page_content: Figure 6: Audit log showing ZSP session details
# category: NarrativeText
# Pagenumber: 11
# image: None
# ----
# page_content: Above you can see that the Ephemeral User was michaelPSGkZSuSzWgmM. This same information will be forwarded to your SIEM solution where you can correlate this data with the event logs that were generated on the machine during the session.
# category: NarrativeText
# Pagenumber: 11
# image: None
# ----
# page_content: \ COOKIE PREFERENCES ) 7
# category: Image
# Pagenumber: 11
# image: extracted_data1/figure-11-35.jpg
# ----
# page_content: Alerting
# category: Title
# Pagenumber: 12
# image: None
# ----
# page_content: Setting up robust alerting mechanisms for connectivity issues between SIA connector servers and the SIA backend is essential for maintaining operational integrity. Utilize monitoring tools to detect connectivity failures, latency spikes, and other network-related issues. Conﬁgure alerts to notify relevant personnel immediately via multiple channels, such as email, SMS, or incident management systems, to ensure prompt response. Deﬁne clear thresholds for what constitutes a connectivity issue, considering factors like response time, packet loss, and connection timeouts. CyberArk recommends enabling notiﬁcations for connector failures. Refer to the Troubleshoot the CyberArk Identity Connector
# category: NarrativeText
# Pagenumber: 12
# image: None
# ----
# page_content: (https://docs.cyberark.com/identity/Latest/en/Content/CoreServices/Connector/Troubleshoot-connector.htm? cshid=1657#Send) documentation for more information on how to conﬁgure this.
# category: NarrativeText
# Pagenumber: 12
# image: None
# ----
# page_content: Break Glass
# category: Title
# Pagenumber: 12
# image: None
# ----
# page_content: For system accounts used for break-glass access, it is recommended to leave the strongest target user (like domain admin, built-in local admins, or root) with a password and/or ssh key access through vaulting and rotation of the credential using PAM self-hosted. If PAM self-hosted is not an option consider physical storage for these most critical break glass accounts.
# category: NarrativeText
# Pagenumber: 12
# image: None
# ----
# page_content: Additional Reading
# category: Title
# Pagenumber: 12
# image: None
# ----
# page_content: Review SIA Security Q&A (cyberark.com (http://cyberark.com)) Solution Brief for information about the security of the product. Reviewing the SIA Security Q&A Solution Brief (https://www.cyberark.com/resources/solution- briefs/dpa-security-q-a) provided by CyberArk is essential for staying informed about the security features related to SIA. This document provides valuable insights into the security architecture, capabilities, and recommended conﬁgurations of the SIA solution, helping organizations to effectively mitigate security risks and ensure compliance with regulatory requirements.
# category: NarrativeText
# Pagenumber: 12
# image: None
# ----
# page_content: The Modernizing Your On-Prem Windows Server Access with CyberArk Secure Infrastructure Access (https://community.cyberark.com/s/article/Modernizing-Your-On-Prem-Windows-Server-Access-with-CyberArk- Dynamic-Privileged-Access-DPA)success blog covers key concepts surrounding modernizing your privileged access for on-prem Windows Servers, addressing challenges, starting from nothing, migrating from an existing PAM service, prioritizing users, and securing that privileged access using CyberArk Secure Infrastructure Access.
# category: NarrativeText
# Pagenumber: 12
# image: None
# ----
# page_content: Blog Type Use Case
# category: NarrativeText
# Pagenumber: 12
# image: None
# ----
# page_content: Target Technology *NIX/Linux;Amazon Web Services (AWS);Google Cloud;Microsoft Azure;Microsoft Windows
# category: Footer
# Pagenumber: 12
# image: None
# ----
# page_content: @ COOKIE PREFERENCES
# category: Image
# Pagenumber: 12
# image: extracted_data1/figure-12-36.jpg
# ----
# page_content: Control Family
# category: Title
# Pagenumber: 13
# image: None
# ----
# page_content: Privilege Access
# category: NarrativeText
# Pagenumber: 13
# image: None
# ----
# page_content: Solution(s) Tag Dynamic Privileged Access
# category: NarrativeText
# Pagenumber: 13
# image: None
# ----
# page_content: Target Audience CyberArk Administrator;Security Engineer/Architect
# category: NarrativeText
# Pagenumber: 13
# image: None
# ----
# page_content: Last Modiﬁed Date
# category: Title
# Pagenumber: 13
# image: None
# ----
# page_content: 21/10/2024 11:52
# category: UncategorizedText
# Pagenumber: 13
# image: None
# ----
# page_content: URL Name
# category: Title
# Pagenumber: 13
# image: None
# ----
# page_content: DPA-Best-Practices
# category: NarrativeText
# Pagenumber: 13
# image: None
# ----
# page_content: Secure Infrastructure Access (SIA) (/s/topic/0TOHt000000gXwYOAU/s…
# category: NarrativeText
# Pagenumber: 13
# image: None
# ----
# page_content: Attachments
# category: Title
# Pagenumber: 13
# image: None
# ----
# page_content: Title
# category: Title
# Pagenumber: 13
# image: None
# ----
# page_content: Title
# category: Title
# Pagenumber: 13
# image: None
# ----
# page_content: Vv __
# category: Title
# Pagenumber: 13
# image: None
# ----
# page_content: Last Modiﬁed
# category: Title
# Pagenumber: 13
# image: None
# ----
# page_content: Vv
# category: Title
# Pagenumber: 13
# image: None
# ----
# page_content: CyberArk Website (https://www.cyberark.com/)
# category: NarrativeText
# Pagenumber: 13
# image: None
# ----
# page_content: Terms & Conditions (https://www.cyberark.com/communities-terms-of-use/)
# category: NarrativeText
# Pagenumber: 13
# image: None
# ----
# page_content: a, COOKIE PREFERENCES ) @ :)
# category: Image
# Pagenumber: 13
# image: extracted_data1/figure-13-37.jpg
# ----
# page_content: Created By
# category: Title
# Pagenumber: 13
# image: None
# ----
# page_content: eS CYBERARK’ The Identity Security Company
# category: Image
# Pagenumber: 13
# image: extracted_data1/figure-13-38.jpg
# ----
# page_content: Privacy Policy (https://www.cyberark.com/privacy-notice/) Community Feedback (MAILTO:km@cyberark.com) Users Access (MAILTO:Users.Access@cyberark.com)
# category: NarrativeText
# Pagenumber: 13
# image: None
# ----
# page_content: @ OOKie PREFERENCES
# category: Image
# Pagenumber: 14
# image: extracted_data1/figure-14-39.jpg
# ----
# page_content: OOKie PREFERENCES
# category: Footer
# Pagenumber: 14
# image: None
# ----
# page_content: CyberArk © 2024 CyberArk Software Ltd. All rights reserved.
# category: NarrativeText
# Pagenumber: 14
# image: None
# ----

# %% [markdown]
# ### Convert Elements into Langchain Documents

# %%
#Convert Elements into Langchain Documents

from langchain.schema import Document
documents =[]
for ele in raw_pdf_elements:
    if ele.text:
        documents.append(
            Document(
            page_content=ele.text,
            metadata={"type": ele.category, "page_number": ele.metadata.page_number}
            )
            )
    elif ele.category =="image" and ele.metadata== "image_path":
        documents.append(Document(
            page_content=f"[Image: {ele.metadata.image_path}]",
            metadata={"type": "image", "page_number":ele.metadata.page_number}
        ))

# %%
documents
# Out:
# [Document(metadata={'type': 'Title', 'page_number': 1}, page_content='Home (/s/)'),
#  Document(metadata={'type': 'Header', 'page_number': 1}, page_content='Engage Updates Product Centers Resources'),
#  Document(metadata={'type': 'Title', 'page_number': 1}, page_content='(Pore'),
#  Document(metadata={'type': 'Title', 'page_number': 1}, page_content='More'),
#  Document(metadata={'type': 'Title', 'page_number': 1}, page_content='Have a Question? Ask the Community'),
#  Document(metadata={'type': 'Title', 'page_number': 1}, page_content='(Q Search...'),
#  Document(metadata={'type': 'Title', 'page_number': 1}, page_content='Search...'),
#  Document(metadata={'type': 'Title', 'page_number': 1}, page_content='Search )'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 1}, page_content='Search'),
#  Document(metadata={'type': 'Title', 'page_number': 1}, page_content='SIA Best Practices: Architecture, Conﬁguration, Security, and Operations'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 1}, page_content='Secure Infrastructure Access (SIA) offers an agentless, SaaS solution for securing privileged access to organizational assets across hybrid and cloud environments. It supports access with zero standing privileges (ZSP) or using vaulted credentials, reducing the risk of standing privileges and including session isolation and monitoring. This document offers the current technical best practices for deploying and conﬁguring SIA securely, architecture for SIA connectors, general conﬁguration of SIA, and the operational aspects associated with maintaining a functional deployment.'),
#  Document(metadata={'type': 'Image', 'page_number': 1}, page_content='Following  Flag '),
#  Document(metadata={'type': 'Title', 'page_number': 1}, page_content='Related Articles'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 1}, page_content='21-Oct-2024 Knowledge Article'),
#  Document(metadata={'type': 'Title', 'page_number': 1}, page_content='Article Total View Count'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 1}, page_content='Security Best Practices for Hardening Your CyberArk Identity Deployment (/s/article/Security-Best- Practices-for-Hardening-Your-CyberArk-Identity- Deployment) 1.48K'),
#  Document(metadata={'type': 'UncategorizedText', 'page_number': 1}, page_content='1,962'),
#  Document(metadata={'type': 'Title', 'page_number': 1}, page_content='Title'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 1}, page_content='SIA Best Practices: Architecture, Conﬁguration, Security, and Operations'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 1}, page_content='Workforce Password Manager Best Practices (/s/article/Workforce-Password-Manager-Best- Practices) 404'),
#  Document(metadata={'type': 'Title', 'page_number': 1}, page_content='Author'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 1}, page_content='Jake DeSantis, Cloud Services Excellence Manager, Security Services'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 1}, page_content='PTA security postures best practices (/s/article/PTA-se‐ curity-postures-best-practices) 948'),
#  Document(metadata={'type': 'Title', 'page_number': 1}, page_content='Blog Details'),
#  Document(metadata={'type': 'Title', 'page_number': 1}, page_content='Introduction'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 1}, page_content='CyberArk Secure Cloud Access (SCA) Policy Best Practices (/s/article/CyberArk-Secure-Cloud-Access-SCA- Policy-Best-Practices) 625'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 1}, page_content='A critical component of any identity security program is privileged session management. Secure Infrastructure Access (SIA) offers an agentless, SaaS solution for securing privileged access to organizational assets across hybrid and cloud environments. It supports access with zero standing privileges (ZSP) or using vaulted credentials, reducing the risk of standing privileges and including session isolation and monitoring. System'),
#  Document(metadata={'type': 'Image', 'page_number': 1}, page_content='@ COOKIE PREFERENCES 7'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 2}, page_content='administrators, DevOps engineers, application owners, and others get VPN-less secure access to Windows, Linux, databases, and Kubernetes via an MFA-secured connection, using their preferred client with the right access for the required duration. For access with vaulted credentials, SIA leverages existing access control policies, requiring only the deployment of the SIA connector.'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 2}, page_content='This document offers the current technical best practices for deploying and conﬁguring SIA securely, architecture for SIA connectors, general conﬁguration of SIA, and the operational aspects associated with maintaining a functional deployment.'),
#  Document(metadata={'type': 'Title', 'page_number': 2}, page_content='Table of Contents'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 2}, page_content='Audience Security Architecture Conﬁguration Operation Additional Reading'),
#  Document(metadata={'type': 'Title', 'page_number': 2}, page_content='Audience'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 2}, page_content='This technical article is designed for those serving the function of CyberArk Administrator and Architect/Subject Matter Expert (https://community.cyberark.com/s/article/Roles-Responsibilities-and-Stafﬁng-Considerations- for-Your-Identity-Security-Program-Part-1) roles. The article can be used by those deploying and operating Secure Infrastructure Access connectors in their environment as well as those responsible for the design and rollout of the solution.'),
#  Document(metadata={'type': 'Title', 'page_number': 2}, page_content='Security'),
#  Document(metadata={'type': 'Title', 'page_number': 2}, page_content='Opt for Zero Standing Privilege (ZSP)'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 2}, page_content='CyberArk recommends leveraging SIA for ZSP wherever possible. ZSP involves dynamically provisioning privileged access to users or systems on an as-needed basis, granting temporary and scoped privileges only when required for speciﬁc tasks or workﬂows. By implementing ZSP, organizations can reduce the number of privileged accounts with permanent access rights. This approach helps to minimize the attack surface and prevent unauthorized users from exploiting prolonged access to critical resources.'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 2}, page_content='For your domain-based accounts, remove access from the AD accounts or groups to the required target machines. If you’re using secondary personal privilege accounts, make sure to delete standing access to the AD accounts. CyberArk recommends a policy-driven approach to controlling local group membership on target systems. Consider using domain group policies or client management software to control the membership of the privileged local groups on target systems.'),
#  Document(metadata={'type': 'Image', 'page_number': 2}, page_content='\\ By istomeConsidarusing COOKIE PREFERENCES }s'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 2}, page_content='Best Practices for Adopting and Implementing Secure Cloud Access (SCA) (/s/article/Best-Practices-for-Adopting- and-Implementing-Secure-Cloud-Access-SCA) 875'),
#  Document(metadata={'type': 'Image', 'page_number': 2}, page_content='Sort by:  S…  Most Recent Activity  t '),
#  Document(metadata={'type': 'Title', 'page_number': 2}, page_content='LiadD (CyberArk Community Manager)'),
#  Document(metadata={'type': 'ListItem', 'page_number': 2}, page_content='(/s/proﬁle/005Ht00000AibqgIAB) (CyberArk) published a new version of this Knowledge Article.'),
#  Document(metadata={'type': 'UncategorizedText', 'page_number': 2}, page_content='21 October 2024 at 11:52'),
#  Document(metadata={'type': 'Title', 'page_number': 2}, page_content='(/s/feed/0D5Ht0000AUrPfHKQV)'),
#  Document(metadata={'type': 'Title', 'page_number': 2}, page_content='Like Comment'),
#  Document(metadata={'type': 'Image', 'page_number': 2}, page_content='e'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 2}, page_content='Write a comment...'),
#  Document(metadata={'type': 'ListItem', 'page_number': 2}, page_content='LiadD (CyberArk Community Manager) (/s/proﬁle/005Ht00000AibqgIAB) (CyberArk) unpublished this Knowledge Article. 21 October 2024 at 11:52 (/s/feed/0D5Ht0000AUrPf7KQF)'),
#  Document(metadata={'type': 'Title', 'page_number': 2}, page_content='Like Comment'),
#  Document(metadata={'type': 'Image', 'page_number': 2}, page_content='e'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 2}, page_content='Write a comment...'),
#  Document(metadata={'type': 'Image', 'page_number': 2}, page_content='$'),
#  Document(metadata={'type': 'ListItem', 'page_number': 2}, page_content='Sal (CyberArk Community Manager)'),
#  Document(metadata={'type': 'ListItem', 'page_number': 2}, page_content='(/s/proﬁle/0052J000009GKbpQAG) (CyberArk) published a new version of this Knowledge Article. 14 October 2024 at 15:37 (/s/feed/0D5Ht0000AUPHxIKQX)'),
#  Document(metadata={'type': 'ListItem', 'page_number': 2}, page_content='Like Comment'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 3}, page_content='In the case of local accounts, identify the privileged users who don’t need ongoing access to target machines and remove their access.'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 3}, page_content='For system accounts used for break-glass access, it is recommended to leave the strongest target user (like domain admin, built-in local admins, or root) with a password and/or ssh key access through vaulting and rotation of the credential using PAM.'),
#  Document(metadata={'type': 'Title', 'page_number': 3}, page_content='Restricting access to Target Systems'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 3}, page_content='Once the SIA deployment is complete and the user adoption rate is high, customers are encouraged to conﬁgure internal network ACLs in a way that allow connectivity from the SIA servers only. For Windows servers, this means allowing only access over port 445 (SMB), 139 & 135 (MSRPC), and 3389 (RDP) and for Linux, 22 (SSH). For more information about SIA network requirements, see Network requirements | CyberArk Docs (https://docs.cyberark.com/DPA/Latest/en/Content/Introduction/dpa_network-requirements.htm).'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 3}, page_content='It’s important to have a contingency plan in place if SIA were to be unavailable. For this, make sure that your network teams can enable access to the target systems from another “Break Glass” session host in the environment. Alternatively, have a plan in place to modify the ACLs in a way that allow access to the systems from another user subnet. Please see the “Break Glass” section below for more information regarding how to handle break glass.'),
#  Document(metadata={'type': 'Title', 'page_number': 3}, page_content='Strong Accounts'),
#  Document(metadata={'type': 'Title', 'page_number': 3}, page_content='About'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 3}, page_content='Strong accounts are privileged accounts with elevated access rights that provide temporary accounts used for ZSP access. Strong accounts can be considered “Service Accounts” in that they are used by the SIA service to automate access for the ZSP ﬂow. To provision ephemeral users, SIA needs to access a strong account, which can create the ephemeral users on the target machines and delete them when the session ends.'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 3}, page_content='Separate strong accounts should be created for Windows and Databases (such as MSSQL). These will need to be onboarded separately in the SIA portal.'),
#  Document(metadata={'type': 'Title', 'page_number': 3}, page_content='Vault & Rotate'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 3}, page_content='Strong accounts can either be speciﬁed in SIA directly or you can conﬁgure SIA to retrieve the account from the vault. Customers are advised to opt for vaulting and rotating the strong accounts. By vaulting strong accounts, Organizations can comply with business security objective and mitigate malicious or risky account usage. Additionally, regular rotation of strong account passwords helps to mitigate the risk of credential theft or misuse by malicious actors. This can be integrated with self-hosted deployments of CyberArk Privileged Access Management (PAM) by leveraging usage plugins to automate the management of strong account credentials.'),
#  Document(metadata={'type': 'Image', 'page_number': 3}, page_content='max—————— COOKIE PREFERENCES ) @ ) ~'),
#  Document(metadata={'type': 'Image', 'page_number': 3}, page_content='e'),
#  Document(metadata={'type': 'Header', 'page_number': 3}, page_content='Write a comment...'),
#  Document(metadata={'type': 'ListItem', 'page_number': 3}, page_content='Sal (CyberArk Community Manager)'),
#  Document(metadata={'type': 'ListItem', 'page_number': 3}, page_content='(/s/proﬁle/0052J000009GKbpQAG) (CyberArk) published a new version of this Knowledge Article. 14 October 2024 at 15:34 (/s/feed/0D5Ht0000AUPHu0KQH)'),
#  Document(metadata={'type': 'Title', 'page_number': 3}, page_content='Like Comment'),
#  Document(metadata={'type': 'Image', 'page_number': 3}, page_content='e'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 3}, page_content='Write a comment...'),
#  Document(metadata={'type': 'Image', 'page_number': 3}, page_content='@ “¥'),
#  Document(metadata={'type': 'ListItem', 'page_number': 3}, page_content='James Creamer (CyberArk)'),
#  Document(metadata={'type': 'ListItem', 'page_number': 3}, page_content='(/s/proﬁle/005500000062PIFAA2) (CyberArk) published a new version of this Knowledge Article. 17 July 2024 at 20:13 (/s/feed/0D5Ht0000AQRLyMKQX)'),
#  Document(metadata={'type': 'Title', 'page_number': 3}, page_content='Like Comment'),
#  Document(metadata={'type': 'Image', 'page_number': 3}, page_content='e'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 3}, page_content='Write a comment...'),
#  Document(metadata={'type': 'ListItem', 'page_number': 3}, page_content='Sal (CyberArk Community Manager)'),
#  Document(metadata={'type': 'ListItem', 'page_number': 3}, page_content='(/s/proﬁle/0052J000009GKbpQAG) (CyberArk) published a new version of this Knowledge Article. 15 July 2024 at 16:01 (/s/feed/0D5Ht0000APt3A7KQJ)'),
#  Document(metadata={'type': 'Title', 'page_number': 3}, page_content='Like Comment'),
#  Document(metadata={'type': 'Image', 'page_number': 3}, page_content='e'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 3}, page_content='Write a comment...'),
#  Document(metadata={'type': 'Title', 'page_number': 4}, page_content='Least Privilege'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 4}, page_content="While the strong accountant may be a member of the Domain Administrators group, this doesn't follow the principle of least privilege and is not considered best practice. To adhere to the principle of least privilege and separation of duties, organizations should subdivide strong accounts into privilege silos. This granular approach helps to ensure that the strong account does not have widespread access throughout your environment. You may also choose to select SIA strong accounts based on credential boundary or network area which may also help align access rights with organizational structures and business requirements."),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 4}, page_content='Strong accounts should be a domain account. CyberArk does not recommend setting up a local account with the same name and the same password on all the target machines. It must be a member of the local Administrators group on each target machine. You can manage this using the Restricted Groups Security Settings in Group Policy.'),
#  Document(metadata={'type': 'Image', 'page_number': 4}, page_content='File Action View Help es%\\acnla\\b am YM Computer Configuration *) Group Name > Members Member Of v Gi Policies 8% Administrators 11 Software Settings v 15 Windows Settings (Gl Name Resolution Policy Administrators Properties ? x {S| Scripts (Startup/Shutdown) 8 Deployed Printers Configure Membership for Administrators vB Securty Settings 55 Account Policies ‘Member of thie group: cca Pots (CYBRIDPASrong Ba 3 Event Log 1 Restricted Groups a A System Services (GB Registry Co File System [Tay Wired Network (IEEE 802.3) Policie Fy Windows Defender Firewall with & Network List Manager Policies Ths gmp s amenber cf £Eif Wireless Network (IEEE 802.11) Pol es re nisi sown belongs Md 5 Public Key Policies 1 Seftware Restriction Policies, [5 Application Control Policies & IP Security Policies on Active Direc Sy Advanced Audit Policy Configural < > Remove Ok Cancel Aoply'),
#  Document(metadata={'type': 'FigureCaption', 'page_number': 4}, page_content='Figure 1: Adding the Strong Account to Local Administrators Group via Group Policy'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 4}, page_content='Additionally, conﬁgure the “Deny Logon through Remote Desktop Services”, “Deny Logon Locally”, “Deny log on as a batch job”, and “Deny log on as a service” for the strong account in domain group policies.'),
#  Document(metadata={'type': 'Image', 'page_number': 4}, page_content='COOKIE PREFERENCES'),
#  Document(metadata={'type': 'Image', 'page_number': 4}, page_content='$'),
#  Document(metadata={'type': 'ListItem', 'page_number': 4}, page_content='Sal (CyberArk Community Manager)'),
#  Document(metadata={'type': 'ListItem', 'page_number': 4}, page_content='(/s/proﬁle/0052J000009GKbpQAG) (CyberArk) published this new Knowledge Article. 10 July 2024 at 04:33 (/s/feed/0D5Ht0000APqoc0KQB)'),
#  Document(metadata={'type': 'Title', 'page_number': 4}, page_content='Like Comment'),
#  Document(metadata={'type': 'Image', 'page_number': 4}, page_content='e'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 4}, page_content='Write a comment...'),
#  Document(metadata={'type': 'UncategorizedText', 'page_number': 4}, page_content='='),
#  Document(metadata={'type': 'Image', 'page_number': 5}, page_content='J Group Policy Management Editor - a x File. Action View Help e9\\an\\/XOS\\bm ‘J DPA-Strong [AIO.CYBRLOCAL] Policy + Policy * Policy Setting a“ Y @& Computer Configuration WiCreate a token object Not Defined ¥ Gi Policies settings (Gj Create global objects Not Defined 2a eer Settings LU) Create permanent shared objects Not Defined > | Name Resolution Policy LU Create symbolic links Not Defined Scripts (Startup/Shutdoown) {G) Debug programs Not Defined Deployed Printers (Gj Deny access to this computer from the network Not Defined vB Security Settings @] > Bil Account Policies Ui Deny log on as a service DPA-Strong v qj Local Policies (Deny tog on locally DPA-Strong > Gi Audit Policy {Gj Deny log on through Remote Desktop Services DPA-Strong > Gj User Rights Assignment (i Enable computer and user accounts to be trusted for delegation Not Defined > dj Security Options Li Force shutdown from a remote system Not Defined > Gj Event Log B Generate security audits Not Defined 1 Restricted Groups {Gj impersonate a client after authentication Not Defined ‘System Services Uj Increase a process working set Not Defined Registry Uj Increase scheduling priority Not Defined File System G) Load and unload device drivers Not Defined Wired Network (IEEE 802.3) Policie Not Defined > Windows Defender Firewall with & Not Defined "Network List Manager Policies UG Log on as a service Not Defined > Eg Wines Newark (EEO | ge ting deity totes ae Y || CA Modify an object label Not Defined g 2 Modif firmware enviranmant valies Not Nafined 9'),
#  Document(metadata={'type': 'FigureCaption', 'page_number': 5}, page_content='Figure 2: User Rights Assignment Restrictions on Domain Strong Account'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 5}, page_content='As an AD account, strong accounts should be disabled for delegation. Select the “Account is sensitive and cannot be delegated” option in the account properties.'),
#  Document(metadata={'type': 'Image', 'page_number': 5}, page_content='DPA-Strong Properties 2 x Pubished Certficates Member Of Password Replication Diskin Object Securty Environment Sessions, Remote control Remote Desktop Services Profle cOM+ Attrbute Edtor General Address Account Profile Telephones Organization User logon name: |DPA-Strong ‘@cybrlocal v] Userlogon name (ere-Windows 2000}: cyeR\\ [DPA-Strong | ‘Logon Hours... Log On To... Dunlock account ‘Account options: DAccount is disabled i O)Smart card is required for interactive logon T)Use only Kerberes DES encryption types forthis account ¥ Account expires Never OEnd of: Saturday July 6, 2024 Cancel || Apply Help'),
#  Document(metadata={'type': 'FigureCaption', 'page_number': 5}, page_content='Figure 3: Conﬁgure Strong Account Object with "Account is sensitive and cannot be delegated"'),
#  Document(metadata={'type': 'Image', 'page_number': 5}, page_content='@ COOKIE PREFERENCES'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 6}, page_content='Although it’s very easy to conﬁgure the strong account as a local admin on target systems, CyberArk recommends taking this a step further to ensure the strong account only has the ability to manage local users on the system and no more.'),
#  Document(metadata={'type': 'Title', 'page_number': 6}, page_content='Domain Controllers'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 6}, page_content='Cyberark does not support and does not recommend enabling connections via RDP to domain controllers using SIA. This is because SIA creates a local user and there are none on domain controllers. Any user created on a domain controller is a domain user, which has more permissions than necessary and is therefore less secure.'),
#  Document(metadata={'type': 'Title', 'page_number': 6}, page_content='Connector Server Hardening'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 6}, page_content='Unlike traditional solutions like Privilege Session Manager (PSM), SIA connectors do not require Remote Desktop Services roles or licensing. This mitigates many vulnerabilities that may arise with the additional footprint. However, hardening the SIA connector servers is still essential for enhancing security and protecting against potential threats and vulnerabilities. Organizations can achieve this by applying CIS Benchmark (https://www.cisecurity.org/benchmark/microsoft_windows_server) or Microsoft Security Baseline (https://www.microsoft.com/en-us/download/details.aspx?id=55319) group policies or conﬁgurations to the SIA connector servers. By doing so, organizations can address common security weaknesses and ensure that the servers are conﬁgured according to established security standards and guidelines.'),
#  Document(metadata={'type': 'Title', 'page_number': 6}, page_content='Avoid Wildcards in Recurring Access Policies'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 6}, page_content='Using wildcards for Hostnames in ZSP policy rules should be avoided due to the risk of granting unfettered access to all machines within an environment. While wildcards may seem convenient, they can inadvertently expose sensitive resources to unauthorized users or roles depending on the risk rating and security level of the asset being accessed and the asset executing the initial session. Instead, organizations should prioritize more precise criteria, such as "starts with" matching, Subscription IDs, VPC identiﬁers, or speciﬁc attributes.'),
#  Document(metadata={'type': 'Image', 'page_number': 6}, page_content='On-premises assets operator Hostname/FODN, Domainysuttic'),
#  Document(metadata={'type': 'Table', 'page_number': 6}, page_content='On-premises assets operator Hostname/FODN, Domainysuttic'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 6}, page_content='Figure 4: Recurring access policy sowing the use of starts with'),
#  Document(metadata={'type': 'Image', 'page_number': 6}, page_content='Gm conn paneeaencee) COOKIE PREFERENCES ) @ :)'),
#  Document(metadata={'type': 'Image', 'page_number': 7}, page_content='Azure assets Custom tag (optional) Add the or evap) Note: In 4 policy tionship m i tags is “ane! Key Value (optional Application CyberArk @ Remove Remove + Aaa'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 7}, page_content='Figure 5: Azure recurring access policy for VMs allowing connectivity to machines matching the tag named Application with a value of "CyberArk"'),
#  Document(metadata={'type': 'Title', 'page_number': 7}, page_content='Architecture'),
#  Document(metadata={'type': 'Title', 'page_number': 7}, page_content='Redundancy and Scalability'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 7}, page_content='To ensure redundancy and scalability, pool multiple connectors by estimating the number of concurrent sessions, latency, and geographical locations through historical logging data showing connections to targets over RDP and SSH. Deploy at least two Connector servers in a Connector pool for high availability and load balancing. Assign connectors and deﬁne target sets; SIA will use an algorithm to choose the SIA connector with the minimum number of active sessions connected to it within all Connector Pools for the target host. Install SIA on a dedicated machine, though PSM/P and SIA can be installed on the same machine if necessary. Refer to the documentation (https://docs.cyberark.com/dpa/latest/en/Content/Setup/dpa-connector- bp.htm#:~:text=Assign%20connectors%20and%20deﬁne%20target%20sets) on where to install connectors.'),
#  Document(metadata={'type': 'Image', 'page_number': 7}, page_content='7 al ge | Mybomain.com ‘Web Taffe, TCP 44 DPISSH/DB Trac: GC) rt'),
#  Document(metadata={'type': 'Image', 'page_number': 7}, page_content='COOKIE PREFERENCES'),
#  Document(metadata={'type': 'Title', 'page_number': 8}, page_content='Proximity to target systems'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 8}, page_content='Deploy SIA Connectors as close to target servers as possible. A target host should be conﬁgured under one Connector Pool. Whenever possible, the closer the Connector Servers in a Connector Pool are to the intended target hosts, the better. If you have a ﬂat network that spans across On-Prem, AWS, Azure, etc., an "On-Prem" connector can be used for all vaulted credentials. In a disparate network that is segmented and not interconnected, use an On-Prem connector in each network zone for vaulted credentials. For ZSP, install the respective type of SIA connector (AWS, Azure, GCP, On-Prem) in each disparate zone. For AWS, if you are onboarding multiple accounts instead of the organization, create a new Pool encompassing all the servers you wish to connect to. Ensure connectivity to any additional accounts and add them to the pool.'),
#  Document(metadata={'type': 'Title', 'page_number': 8}, page_content='Operating System Considerations'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 8}, page_content='It’s important to understand the factors that may inﬂuence the decision between installing SIA connectors on Windows or on Linux. First, it’s important to call out that there is no performance difference between a SIA connector installed on Linux vs. installed on Windows. However, if you need to connect to Windows machines via ZSP, at least one of the connectors in the pool must be installed on Windows, to handle the provisioning. SIA for RDP and SIA for SSH work by forwarding the TCP trafﬁc, but you do need a Windows Connector to use the ZSP functionality on Windows.'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 8}, page_content='You can deploy more Linux connectors if you want more redundancy for connectivity. This is more common in cloud infrastructure than on-premises. If a particular network contains Linux only, then there is no need to install a Windows connector into the environment. Consider network requirements when deploying the connector servers. Users will need access to CyberArk’s SaaS over ports 443 and 22, and access to the targets from the connectors over port 22.'),
#  Document(metadata={'type': 'Title', 'page_number': 8}, page_content='Conﬁguration'),
#  Document(metadata={'type': 'Title', 'page_number': 8}, page_content='Recurring Access Policies'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 8}, page_content='Limit policies to boost performance. In practice, this means carefully deﬁning and restricting the scope of policies applied within SIA to ensure that they do not unnecessarily grow and cause performance bottlenecks. Limiting policies can involve setting precise criteria for access, reducing the number of simultaneous operations allowed, and optimizing the rules to ensure they are as efﬁcient as possible. This helps maintain a high level of performance and responsiveness within the SIA environment.'),
#  Document(metadata={'type': 'Title', 'page_number': 8}, page_content='Access Policy Naming'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 8}, page_content='The ﬁrst item that you deﬁne when creating a recurring access policy is the name. Consider using ﬁelds like the following when creating your access policy naming convention:'),
#  Document(metadata={'type': 'Table', 'page_number': 8}, page_content='Deﬁnition Example The type of target the access policy PRD; DEV; QA applies to. This could be Production targets, Development environment targets, or QA.'),
#  Document(metadata={'type': 'Title', 'page_number': 8}, page_content='Field Name'),
#  Document(metadata={'type': 'Title', 'page_number': 8}, page_content='Environment'),
#  Document(metadata={'type': 'Image', 'page_number': 8}, page_content='| @ COOKIE PREFERENCES'),
#  Document(metadata={'type': 'Table', 'page_number': 9}, page_content='Location The location the targets exist. This may be NA; EMEA; APJ; EU; more applicable to customers who have LATAM targets spread globally. Application Some customers will deﬁne their targets in <Application sets that are based on the applications Abbreviation> they host. Criticality Consider deﬁning access policy names PH; PM; PL; NPH; based on the criticality of the targets that NPM; MPL the policy allows users to access. These can be in the form of “Production High/Mid/Low”; Non-Production High/Mid/Low; etc. Time Frame Consider including other recurring access Jun-Jul; Q1; H2; etc. policy details like the timeframe when access is meant to be permitted.'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 9}, page_content='CyberArk recommends also relying on the existing naming convention ﬁelds that have been developed within your environment. For instance, you may already have a naming convention for targets that you use in your environment such as WIN-PH-NA-PRD-SRV-002 which would deﬁne the second windows server that is a production high-impact system in North America. Your recurring access policy could be named similar to this, allowing users to access those Windows Production High-impact systems in North America. i.e. WIN-PH-NA- PRD'),
#  Document(metadata={'type': 'Title', 'page_number': 9}, page_content='Time Frame'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 9}, page_content='The recurring access policy timeframe can be used to set a span of time that allows the deﬁned members to connect to the deﬁned targets. Use the time frame in scenarios where you need to limit users access only during a project timeline, contract timelines, or when you must put a timeframe around the access during certain change windows. The timeframe in an access policy can be automated in these scenarios using the startDate and endDate parameters in the update authorization policy'),
#  Document(metadata={'type': 'Title', 'page_number': 9}, page_content='(https://docs.cyberark.com/DPA/Latest/en/Content/APIs/dpa_policies.htm) API.'),
#  Document(metadata={'type': 'Title', 'page_number': 9}, page_content='Access Rules'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 9}, page_content='Access rules in recurring access policies deﬁne if the rule applies to windows and/or linux machines, which users or roles the access rule applies (members), the days of the week that the access is permitted, and the timeframe on those days that access is permitted. Access rules also deﬁne session settings like how long the sessions can be and how much idle time is permitted before the session is automatically closed. Members: When deﬁning the members in an policy, opt for using roles rather than individual users when possible. Using roles instead of users allows admins to more easily control and deﬁne which users have access to targets in the environment. Consider creating roles speciﬁc to the recurring access policies and naming them to align with the recurring access policy name.'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 9}, page_content='Days of the week and Timeframe: Deﬁne the days of the week that make the most sense for allowing access to the targets Set the timeframe during business hours or when work on those targets is most necessary. You'),
#  Document(metadata={'type': 'Image', 'page_number': 9}, page_content='‘en @ COOKIE PREFERENCES ) _'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 10}, page_content='may want to be more or less restrictive based on the criticality of the resources in question. If your recurring access policies allow access to dev systems, you may want to be more lenient with the access; for production systems, think about how the access timeframe can be more restrictive. Length of sessions and permitted idle time: The length of sessions should be a balance between how much time is required by the members to perform their work on average. Being too restrictive with the length of the session can cause the sessions to close sooner than the work can be completed. It’s important to allow enough time for the work to be completed. Deﬁne policies for lower-risk targets where the length of the sessions and the idle time are longer. For more critical targets, carefully deﬁne the length of the sessions and the idle time just enough to allow users to perform their work and end the sessions if they are idle for an unacceptable length of time. For these more critical systems, no more than 2 hours of idle time should be considered.'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 10}, page_content='For windows assets, the access rules can deﬁne which group that the strong account will add the ephemeral user to. The principal of least privilege should be followed here. CyberArk recommends deﬁning a custom group on the target systems using group policy and customizing user rights assignments for that group to granularly limit what the user can do on those systems. Alternatively, customers can use built-in groups like Administrators, Power Users, or Remote Desktop users. In this case, choose the group that grants the lowest level of privilege while still allowing the end user to accomplish their tasks.'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 10}, page_content='For Linux assets, the access rules can deﬁne which local privileged user the session will assume when SIA connects the end user to the target system. CyberArk recommends deﬁning a user with only the right privileges on the system for the connection, disabling password and ssh key login for that user, and allowing only ssh certiﬁcate-based auth. For each authorized connection, SIA generates and signs an SSH certiﬁcate with the CA private key which is used to authenticate the end user to the target machine as the existing local user of the target machine. This SSH certiﬁcate is invalidated for further use within minutes, so that no one else can use it. Every new authorized connection request, even by the same user to the same target, generates a new SSH certiﬁcate. You can read about how to manage the SSH CA public key for SIA connections to Linux systems here'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 10}, page_content='(https://docs.cyberark.com/dpa/latest/en/Content/Setup/dpa_deploy_public_key.htm).'),
#  Document(metadata={'type': 'Title', 'page_number': 10}, page_content='Attributed Based Access Control'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 10}, page_content='SIA can connect users to Windows and Linux targets in cloud environments like AWS, Azure, and GCP. Customers may use a simple windows connector to allow their users to do so, however it’s better practice to use the built-in attribute-based access control to more granularly deﬁne access policies. Attribute-based access control in recurring access policies deﬁne both the available platform resources and the level of privileges allowed to the end user. The access policy assigns an access proﬁle to the end user, which contains permissions for accessing the target.'),
#  Document(metadata={'type': 'Table', 'page_number': 10}, page_content='AWS Azure GCP Account Subscription IDs Project IDs Region VPC Regions Resource Groups Regions VPC Networks'),
#  Document(metadata={'type': 'Image', 'page_number': 10}, page_content='VPC '),
#  Document(metadata={'type': 'Header', 'page_number': 11}, page_content='Custom Tags*'),
#  Document(metadata={'type': 'Title', 'page_number': 11}, page_content='VNet IDs'),
#  Document(metadata={'type': 'ListItem', 'page_number': 11}, page_content='Labels'),
#  Document(metadata={'type': 'Title', 'page_number': 11}, page_content='Custom Tags*'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 11}, page_content='*Using custom tags and labels gives you very granular control over your cloud assets. Many customers already leverage custom tags in their environments and may leverage those same tags in SIA’s recurring access policies.'),
#  Document(metadata={'type': 'Title', 'page_number': 11}, page_content='Operation'),
#  Document(metadata={'type': 'Title', 'page_number': 11}, page_content='Monitoring'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 11}, page_content='Regular monitoring of the SIA service on connector servers is crucial for maintaining system health and performance. Utilize monitoring tools to track key metrics such as CPU usage, memory utilization, network throughput, and disk I/O. Implement comprehensive logging to capture detailed information about SIA operations, including connection attempts, successes, and failures. Regularly review these logs to identify patterns or anomalies that could indicate potential issues. Establish a baseline of normal operating parameters to quickly detect deviations that may require attention. Additionally, consider setting up automated monitoring solutions that provide real-time visibility into the SIA service’s status and performance, helping to proactively address issues before they escalate.'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 11}, page_content='When using Zero Standing Privilege, it’s important to consider how access to target systems with ephemeral accounts is done to be able to properly audit these sessions. Below is an example of a session audit log that shows the connection details for a session that used SIA for JIT access:'),
#  Document(metadata={'type': 'Image', 'page_number': 11}, page_content='Activities Tecan 4 re sername eton — serace michael. mcaughey@cyberark.cloud.20885 has discon... 9.2004 14708 4M DPAWindowssesion andes micusimenugheeyberadoudzoees Endy rege css vent detalls Service dita 19.2024 11338 DA Winsouesemionansas — minasienugnaSeybearecousannss aa yea Prag hess DPAWindowssesion started micusimenugheeyberadoudz0ees Stay rege Accs'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 11}, page_content='Figure 6: Audit log showing ZSP session details'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 11}, page_content='Above you can see that the Ephemeral User was michaelPSGkZSuSzWgmM. This same information will be forwarded to your SIEM solution where you can correlate this data with the event logs that were generated on the machine during the session.'),
#  Document(metadata={'type': 'Image', 'page_number': 11}, page_content='\\ COOKIE PREFERENCES ) 7'),
#  Document(metadata={'type': 'Title', 'page_number': 12}, page_content='Alerting'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 12}, page_content='Setting up robust alerting mechanisms for connectivity issues between SIA connector servers and the SIA backend is essential for maintaining operational integrity. Utilize monitoring tools to detect connectivity failures, latency spikes, and other network-related issues. Conﬁgure alerts to notify relevant personnel immediately via multiple channels, such as email, SMS, or incident management systems, to ensure prompt response. Deﬁne clear thresholds for what constitutes a connectivity issue, considering factors like response time, packet loss, and connection timeouts. CyberArk recommends enabling notiﬁcations for connector failures. Refer to the Troubleshoot the CyberArk Identity Connector'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 12}, page_content='(https://docs.cyberark.com/identity/Latest/en/Content/CoreServices/Connector/Troubleshoot-connector.htm? cshid=1657#Send) documentation for more information on how to conﬁgure this.'),
#  Document(metadata={'type': 'Title', 'page_number': 12}, page_content='Break Glass'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 12}, page_content='For system accounts used for break-glass access, it is recommended to leave the strongest target user (like domain admin, built-in local admins, or root) with a password and/or ssh key access through vaulting and rotation of the credential using PAM self-hosted. If PAM self-hosted is not an option consider physical storage for these most critical break glass accounts.'),
#  Document(metadata={'type': 'Title', 'page_number': 12}, page_content='Additional Reading'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 12}, page_content='Review SIA Security Q&A (cyberark.com (http://cyberark.com)) Solution Brief for information about the security of the product. Reviewing the SIA Security Q&A Solution Brief (https://www.cyberark.com/resources/solution- briefs/dpa-security-q-a) provided by CyberArk is essential for staying informed about the security features related to SIA. This document provides valuable insights into the security architecture, capabilities, and recommended conﬁgurations of the SIA solution, helping organizations to effectively mitigate security risks and ensure compliance with regulatory requirements.'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 12}, page_content='The Modernizing Your On-Prem Windows Server Access with CyberArk Secure Infrastructure Access (https://community.cyberark.com/s/article/Modernizing-Your-On-Prem-Windows-Server-Access-with-CyberArk- Dynamic-Privileged-Access-DPA)success blog covers key concepts surrounding modernizing your privileged access for on-prem Windows Servers, addressing challenges, starting from nothing, migrating from an existing PAM service, prioritizing users, and securing that privileged access using CyberArk Secure Infrastructure Access.'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 12}, page_content='Blog Type Use Case'),
#  Document(metadata={'type': 'Footer', 'page_number': 12}, page_content='Target Technology *NIX/Linux;Amazon Web Services (AWS);Google Cloud;Microsoft Azure;Microsoft Windows'),
#  Document(metadata={'type': 'Image', 'page_number': 12}, page_content='@ COOKIE PREFERENCES'),
#  Document(metadata={'type': 'Title', 'page_number': 13}, page_content='Control Family'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 13}, page_content='Privilege Access'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 13}, page_content='Solution(s) Tag Dynamic Privileged Access'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 13}, page_content='Target Audience CyberArk Administrator;Security Engineer/Architect'),
#  Document(metadata={'type': 'Title', 'page_number': 13}, page_content='Last Modiﬁed Date'),
#  Document(metadata={'type': 'UncategorizedText', 'page_number': 13}, page_content='21/10/2024 11:52'),
#  Document(metadata={'type': 'Title', 'page_number': 13}, page_content='URL Name'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 13}, page_content='DPA-Best-Practices'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 13}, page_content='Secure Infrastructure Access (SIA) (/s/topic/0TOHt000000gXwYOAU/s…'),
#  Document(metadata={'type': 'Title', 'page_number': 13}, page_content='Attachments'),
#  Document(metadata={'type': 'Title', 'page_number': 13}, page_content='Title'),
#  Document(metadata={'type': 'Title', 'page_number': 13}, page_content='Title'),
#  Document(metadata={'type': 'Title', 'page_number': 13}, page_content='Vv __'),
#  Document(metadata={'type': 'Title', 'page_number': 13}, page_content='Last Modiﬁed'),
#  Document(metadata={'type': 'Title', 'page_number': 13}, page_content='Vv'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 13}, page_content='CyberArk Website (https://www.cyberark.com/)'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 13}, page_content='Terms & Conditions (https://www.cyberark.com/communities-terms-of-use/)'),
#  Document(metadata={'type': 'Image', 'page_number': 13}, page_content='a, COOKIE PREFERENCES ) @ :)'),
#  Document(metadata={'type': 'Title', 'page_number': 13}, page_content='Created By'),
#  Document(metadata={'type': 'Image', 'page_number': 13}, page_content='eS CYBERARK’ The Identity Security Company'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 13}, page_content='Privacy Policy (https://www.cyberark.com/privacy-notice/) Community Feedback (MAILTO:km@cyberark.com) Users Access (MAILTO:Users.Access@cyberark.com)'),
#  Document(metadata={'type': 'Image', 'page_number': 14}, page_content='@ OOKie PREFERENCES'),
#  Document(metadata={'type': 'Footer', 'page_number': 14}, page_content='OOKie PREFERENCES'),
#  Document(metadata={'type': 'NarrativeText', 'page_number': 14}, page_content='CyberArk © 2024 CyberArk Software Ltd. All rights reserved.')]

# %% [markdown]
# ### Embedd Documents

# %%
# Embedd documents
import os
os.environ["HF_TOKEN"]=os.getenv("HF_TOKEN")

from langchain.embeddings import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")
# Out:
# /var/folders/1s/70xy4dvs6mn0zqfz6nvhbypw0000gn/T/ipykernel_8919/2688645502.py:6: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")

# %% [markdown]
# ### Store in Milvus

# %%
# Store in Milvus
# Milvus Lite 
### The easiest way to prototype is to use Milvus Lite, where everything is stored in a local vector database file. Only the Flat index can be used.

from langchain_milvus import Milvus

URI = "./milvus_example03.db"

vector_store = Milvus(
    embedding_function=embeddings,
    connection_args={"uri": URI},
    index_params={"index_type": "FLAT", "metric_type": "L2"},
)

# %%
from uuid import uuid4
uuids=[]
for i in range(len(documents)):
    uuids.append(str(uuid4()))

uuids
# Out:
# ['b714d755-0bdc-4e9a-9160-cc192587b103',
#  '004e9889-b257-408b-8fc9-5cf34f882a06',
#  'b5f51b75-d5d8-4648-aca0-934594163545',
#  '4fcf5e10-073f-437c-a8a4-8a7d345c4a99',
#  '6c437762-fc63-4e1f-97cc-008938d0fdda',
#  '5d116ea6-eccd-4352-89a5-e59f045f8dee',
#  '267ecde0-0fa8-4348-bd2f-9b5c9b01c004',
#  '52dcb713-2fec-4145-8282-2561a87fc83c',
#  '033c869c-d766-4a0a-8478-f852da7d1fca',
#  'f8584f45-6554-4e16-941a-798cee70f65a',
#  '92a064b4-ba0c-4cc6-8af1-e250b97aed4e',
#  '889fdd19-eedb-4e80-a1a6-f6c69c4e14b6',
#  'eb9786bc-d2e7-4528-8960-07e6b4999721']

# %% [markdown]
# ### Creation of retriever class for vector store

# %%
#creation of retriever class for vector store

retriever =vector_store.as_retriever(
        search_type="similarity_score_threshold",
        search_kwargs={'score_threshold': 0.6,'k': 6} #hyperparameter
)

# %% [markdown]
# ### Querying the VectorStore

# %%
# Query directly - Similarity search

res1= vector_store.similarity_search(query="what is strong accounts",k=3)
res1
for res in res1:
    print(f"# {res.page_content}")
# Out:
# # Strong Accounts
# # Strong accounts are privileged accounts with elevated access rights that provide temporary accounts used for ZSP access. Strong accounts can be considered “Service Accounts” in that they are used by the SIA service to automate access for the ZSP ﬂow. To provision ephemeral users, SIA needs to access a strong account, which can create the ephemeral users on the target machines and delete them when the session ends.
# # Strong accounts can either be speciﬁed in SIA directly or you can conﬁgure SIA to retrieve the account from the vault. Customers are advised to opt for vaulting and rotating the strong accounts. By vaulting strong accounts, Organizations can comply with business security objective and mitigate malicious or risky account usage. Additionally, regular rotation of strong account passwords helps to mitigate the risk of credential theft or misuse by malicious actors. This can be integrated with self-hosted deployments of CyberArk Privileged Access Management (PAM) by leveraging usage plugins to automate the management of strong account credentials.

# %%
# Query directly - Similarity search with score

res2= vector_store.similarity_search_with_score(query="what is strong accounts",k=3)
res2
# Out:
# [(Document(metadata={'page_number': 3, 'pk': 'e00ce1d6-2fd3-4b1e-b542-e4ce9ddd4fcc', 'type': 'Title'}, page_content='Strong Accounts'),
#   0.3603437840938568),
#  (Document(metadata={'page_number': 3, 'pk': 'e69da931-6574-4959-80d1-f938b9e3b75c', 'type': 'NarrativeText'}, page_content='Strong accounts are privileged accounts with elevated access rights that provide temporary accounts used for ZSP access. Strong accounts can be considered “Service Accounts” in that they are used by the SIA service to automate access for the ZSP ﬂow. To provision ephemeral users, SIA needs to access a strong account, which can create the ephemeral users on the target machines and delete them when the session ends.'),
#   0.6745815277099609),
#  (Document(metadata={'page_number': 3, 'pk': 'a1844abd-ec22-4fc4-9bef-25a3f840644f', 'type': 'NarrativeText'}, page_content='Strong accounts can either be speciﬁed in SIA directly or you can conﬁgure SIA to retrieve the account from the vault. Customers are advised to opt for vaulting and rotating the strong accounts. By vaulting strong accounts, Organizations can comply with business security objective and mitigate malicious or risky account usage. Additionally, regular rotation of strong account passwords helps to mitigate the risk of credential theft or misuse by malicious actors. This can be integrated with self-hosted deployments of CyberArk Privileged Access Management (PAM) by leveraging usage plugins to automate the management of strong account credentials.'),
#   0.7022835612297058)]

# %%
for res,score in res2:
    print(f"* {res.page_content},{score:3f}")
# Out:
# * Strong Accounts,0.360344
# * Strong accounts are privileged accounts with elevated access rights that provide temporary accounts used for ZSP access. Strong accounts can be considered “Service Accounts” in that they are used by the SIA service to automate access for the ZSP ﬂow. To provision ephemeral users, SIA needs to access a strong account, which can create the ephemeral users on the target machines and delete them when the session ends.,0.674582
# * Strong accounts can either be speciﬁed in SIA directly or you can conﬁgure SIA to retrieve the account from the vault. Customers are advised to opt for vaulting and rotating the strong accounts. By vaulting strong accounts, Organizations can comply with business security objective and mitigate malicious or risky account usage. Additionally, regular rotation of strong account passwords helps to mitigate the risk of credential theft or misuse by malicious actors. This can be integrated with self-hosted deployments of CyberArk Privileged Access Management (PAM) by leveraging usage plugins to automate the management of strong account credentials.,0.702284

# %%
# search_type = ""similarity"" 
# Returns the documents most similar to the query using a distance metric (like cosine similarity or Euclidean distance) between embedding vectors.

retriever =vector_store.as_retriever(
        #search_type="similarity_score_threshold",
        search_type="similarity",
        search_kwargs={'k': 6} #hyperparameter
)
response_1 =retriever.invoke("what is strong accounts?")

for doc in response_1:
    print(doc.page_content)
# Out:
# Strong Accounts
# Strong accounts are privileged accounts with elevated access rights that provide temporary accounts used for ZSP access. Strong accounts can be considered “Service Accounts” in that they are used by the SIA service to automate access for the ZSP ﬂow. To provision ephemeral users, SIA needs to access a strong account, which can create the ephemeral users on the target machines and delete them when the session ends.
# Strong accounts can either be speciﬁed in SIA directly or you can conﬁgure SIA to retrieve the account from the vault. Customers are advised to opt for vaulting and rotating the strong accounts. By vaulting strong accounts, Organizations can comply with business security objective and mitigate malicious or risky account usage. Additionally, regular rotation of strong account passwords helps to mitigate the risk of credential theft or misuse by malicious actors. This can be integrated with self-hosted deployments of CyberArk Privileged Access Management (PAM) by leveraging usage plugins to automate the management of strong account credentials.
# While the strong accountant may be a member of the Domain Administrators group, this doesn't follow the principle of least privilege and is not considered best practice. To adhere to the principle of least privilege and separation of duties, organizations should subdivide strong accounts into privilege silos. This granular approach helps to ensure that the strong account does not have widespread access throughout your environment. You may also choose to select SIA strong accounts based on credential boundary or network area which may also help align access rights with organizational structures and business requirements.
# Figure 3: Conﬁgure Strong Account Object with "Account is sensitive and cannot be delegated"
# Although it’s very easy to conﬁgure the strong account as a local admin on target systems, CyberArk recommends taking this a step further to ensure the strong account only has the ability to manage local users on the system and no more.

# %%
# search_type = ""similarity_score_threshold"" 
# Only returns documents with a similarity score above a certain threshold.

retriever =vector_store.as_retriever(
        search_type="similarity_score_threshold",
        search_kwargs={"score_threshold": 0.6} #hyperparameter
)
response_2 =retriever.invoke("what is strong accounts?")

for doc in response_2:
    print(doc.page_content)
# Out:
# Strong Accounts
# Strong accounts are privileged accounts with elevated access rights that provide temporary accounts used for ZSP access. Strong accounts can be considered “Service Accounts” in that they are used by the SIA service to automate access for the ZSP ﬂow. To provision ephemeral users, SIA needs to access a strong account, which can create the ephemeral users on the target machines and delete them when the session ends.
# Strong accounts can either be speciﬁed in SIA directly or you can conﬁgure SIA to retrieve the account from the vault. Customers are advised to opt for vaulting and rotating the strong accounts. By vaulting strong accounts, Organizations can comply with business security objective and mitigate malicious or risky account usage. Additionally, regular rotation of strong account passwords helps to mitigate the risk of credential theft or misuse by malicious actors. This can be integrated with self-hosted deployments of CyberArk Privileged Access Management (PAM) by leveraging usage plugins to automate the management of strong account credentials.
# While the strong accountant may be a member of the Domain Administrators group, this doesn't follow the principle of least privilege and is not considered best practice. To adhere to the principle of least privilege and separation of duties, organizations should subdivide strong accounts into privilege silos. This granular approach helps to ensure that the strong account does not have widespread access throughout your environment. You may also choose to select SIA strong accounts based on credential boundary or network area which may also help align access rights with organizational structures and business requirements.

# %%
# search_type = "mmr" 
# Maximal Marginal Relevance 
# # It tries to avoid redundancy among results.
retriever =vector_store.as_retriever(
        search_type="mmr",
        search_kwargs={'k': 6} #hyperparameter
)
res3 =retriever.invoke("what is strong accounts?")
res3
for doc in res3:
    print(doc.page_content)
# Out:
# Strong Accounts
# Strong accounts are privileged accounts with elevated access rights that provide temporary accounts used for ZSP access. Strong accounts can be considered “Service Accounts” in that they are used by the SIA service to automate access for the ZSP ﬂow. To provision ephemeral users, SIA needs to access a strong account, which can create the ephemeral users on the target machines and delete them when the session ends.
# While the strong accountant may be a member of the Domain Administrators group, this doesn't follow the principle of least privilege and is not considered best practice. To adhere to the principle of least privilege and separation of duties, organizations should subdivide strong accounts into privilege silos. This granular approach helps to ensure that the strong account does not have widespread access throughout your environment. You may also choose to select SIA strong accounts based on credential boundary or network area which may also help align access rights with organizational structures and business requirements.
# Figure 3: Conﬁgure Strong Account Object with "Account is sensitive and cannot be delegated"
# Security
# Although it’s very easy to conﬁgure the strong account as a local admin on target systems, CyberArk recommends taking this a step further to ensure the strong account only has the ability to manage local users on the system and no more.

# %% [markdown]
# ### # Reranking
# After the first stage of retrieval, we need to rerank the candidates to get a better result.

# %%
# Reranking
from langchain_openai import ChatOpenAI
from langchain.retrievers.document_compressors import LLMListwiseRerank

llm = ChatOpenAI(model="gpt-4o")
reranker = LLMListwiseRerank.from_llm(llm=llm)

# Apply reranking
reranked_docs = reranker.compress_documents(documents=res3, query="what is strong account?")

# Show results
for doc in reranked_docs:
    print(doc.page_content)
# Out:
# Strong accounts are privileged accounts with elevated access rights that provide temporary accounts used for ZSP access. Strong accounts can be considered “Service Accounts” in that they are used by the SIA service to automate access for the ZSP ﬂow. To provision ephemeral users, SIA needs to access a strong account, which can create the ephemeral users on the target machines and delete them when the session ends.
# While the strong accountant may be a member of the Domain Administrators group, this doesn't follow the principle of least privilege and is not considered best practice. To adhere to the principle of least privilege and separation of duties, organizations should subdivide strong accounts into privilege silos. This granular approach helps to ensure that the strong account does not have widespread access throughout your environment. You may also choose to select SIA strong accounts based on credential boundary or network area which may also help align access rights with organizational structures and business requirements.
# Although it’s very easy to conﬁgure the strong account as a local admin on target systems, CyberArk recommends taking this a step further to ensure the strong account only has the ability to manage local users on the system and no more.

# %% [markdown]
# ### RAG Pipeline

# %%
# RAG part

# LLM
from langchain_groq import ChatGroq
llm = ChatGroq(model ="llama-3.3-70b-versatile")

# %%
# prompt
from langchain import hub
prompt = hub.pull("rlm/rag-prompt")

# %%
# checking the prompt template variables...
import pprint
pprint.pprint(prompt.messages)
# Out:
# [HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: {question} \nContext: {context} \nAnswer:"), additional_kwargs={})]

# %%
# output parser
from langchain_core.output_parsers import StrOutputParser

# %%
# chain creation
from langchain_core.runnables import RunnablePassthrough, RunnableLambda

def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

chain =(
    { 
      "context":retriever| RunnableLambda(format_docs),
      "question":RunnablePassthrough()
     }
    |prompt
    |llm
    |StrOutputParser()
)

# %%
response=chain.invoke("Explain the monitoring part of SIA operation?")
print(response)
# Out:
# The monitoring part of SIA operation involves tracking key metrics such as CPU usage, memory utilization, and network throughput using monitoring tools. Comprehensive logging is also implemented to capture detailed information about SIA operations, including connection attempts and failures, to identify patterns or anomalies. Regular review of logs and establishment of a baseline of normal operating parameters help detect deviations that may require attention.

# %%
response=chain.invoke("list me the related articles for Hardening??")
print(response)
# Out:
# There is a related article titled "Security Best Practices for Hardening Your CyberArk Identity Deployment". This article provides security best practices for hardening CyberArk Identity deployments. The exact list of related articles is not fully provided in the given context, but the mentioned article is one of them.
